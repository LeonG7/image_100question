# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

img = cv2.imread("assets/imori.jpg")
plt.imshow(img)      #[R G B]

# %%
img = img[:,:,[2,1,0]]    #[B,G，R]cv2中使用的B,G,R
plt.imshow(img)

# %%
img.shape
# Out:
# (128, 128, 3)

# %%
_img = img.astype(np.float32)
plt.imshow(_img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img[20,30]
img[20, 30:33,1:2]
# Out:
# array([232, 178, 171], dtype=uint8)
# array([[178],
#        [156],
#        [ 85]], dtype=uint8)

# %%
img2 = img
img2[:20,:20] = 0
plt.imshow(img2)

# %%
img2 = img.copy().astype(np.float32)
img2[60:100,60:100,2] = 260
plt.imshow(img2.astype(np.uint8))
#大于256的值，转为uint8之后会用原来的值模上256,260-256 = 4

# %%
cv2.imwrite("sample.jpg",img2.astype(np.uint8))
# Out:
# True

# %%
img3 = img
img3[:,:64]= img3[:,:64,[2,1,0]]
plt.imshow(img3)
